# %% [markdown]
# # <i><b> Flight Price Prediction EDA

# %% [markdown]
# ## Importing Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Reading the Dataset

# %%
df = pd.read_excel('flight_price.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# ## Converting features from catagorical to numerical.

# %% [markdown]
# ### Date of Journey

# %%
df['Date'] = df['Date_of_Journey'].str.split('/').str[0]
df['Months'] = df['Date_of_Journey'].str.split('/').str[1]
df['Year'] = df['Date_of_Journey'].str.split('/').str[2]

# Converting the string data type to numerical.
df['Date'] = df['Date'].astype(int)
df['Months'] = df['Months'].astype(int)
df['Year'] = df['Year'].astype(int)

df.drop('Date_of_Journey', axis=1, inplace=True)

# %%
### Droping Route
df.drop('Route', axis=1, inplace=True)

# %%
df.head(2)
# Out:
#      Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0     IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1  Air India   Kolkata    Banglore    05:50         13:15   7h 25m
#
#   Total_Stops Additional_Info  Price  Date  Months  Year
# 0    non-stop         No info   3897    24       3  2019
# 1     2 stops         No info   7662     1       5  2019

# %% [markdown]
# ### Dep_Time

# %%
df['Dep_hour'] = df['Dep_Time'].str.split(':').str[0]
df['Dep_min'] = df['Dep_Time'].str.split(':').str[1]


# Converting the string data type to numerical.
df['Dep_hour']= df['Dep_hour'].astype(int)
df['Dep_min'] = df['Dep_min'].astype(int)


df.drop('Dep_Time', axis=1, inplace=True)

# %%
df.head(3)
# Out:
#        Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0       IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1    Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
# 2  Jet Airways     Delhi      Cochin  04:25 10 Jun      19h     2 stops
#
#   Additional_Info  Price  Date  Months  Year  Dep_hour  Dep_min
# 0         No info   3897    24       3  2019        22       20
# 1         No info   7662     1       5  2019         5       50
# 2         No info  13882     9       6  2019         9       25

# %% [markdown]
# ### Arrival_Time

# %%
df['Arr_hour'] = df['Arrival_Time'].str.split(' ').str[0].str.split(':').str[0]
df['Arr_min'] = df['Arrival_Time'].str.split(' ').str[0].str.split(':').str[1]


# Converting the string data type to numerical.
df['Arr_hour']= df['Arr_hour'].astype(int)
df['Arr_min'] = df['Arr_min'].astype(int)


df.drop('Arrival_Time', axis=1, inplace=True)

# %%
df.head(3)
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
#
#    Price  Date  Months  Year  Dep_hour  Dep_min  Arr_hour  Arr_min
# 0   3897    24       3  2019        22       20         1       10
# 1   7662     1       5  2019         5       50        13       15
# 2  13882     9       6  2019         9       25         4       25

# %% [markdown]
# ### Duration

# %%
df['hour'] = df['Duration'].str.split(' ').str[0].str.split('h').str[0]
df['min'] = df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# Replacing NaN value with 0.
df['min'] = df['min'].replace(np.nan, '0')
df["hour"] =  pd.to_numeric(df['hour'], errors='coerce')

# Converting the string datatype to numerical.
df['hour'] = df['hour'].astype(int)
df['min'] = df['min'].astype(int)

# df.drop('Duration', axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# c:\Users\Prateek Kumar\OneDrive\Desktop\Python\15_EDA\04_eda_flight_price.ipynb Cell 21 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/Prateek%20Kumar/OneDrive/Desktop/Python/15_EDA/04_eda_flight_price.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> df["hour"] =  pd.to_numeric(df['hour'], errors='coerce')
#       <a href='vscode-notebook-cell:/c%3A/Users/Prateek%20Kumar/OneDrive/Desktop/Python/15_EDA/04_eda_flight_price.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> # Converting the string datatype to numerical.
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Prateek%20Kumar/OneDrive/Desktop/Python/15_EDA/04_eda_flight_price.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> df['hour'] = df['hour'].astype(int)
#      <a href='vscode-notebook-cell:/c%3A/Users/Prateek%20Kumar/OneDrive/Desktop/Python/15_EDA/04_eda_flight_price.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a> df['min'] = df['min'].astype(int)
#      <a href='vscode-notebook-cell:/c%3A/Users/Prateek%20Kumar/OneDrive/Desktop/Python/15_EDA/04_eda_flight_price.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a> # df.drop('Duration', axis=1, inplace= True)
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
#     449 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:140, in astype_nansafe(arr, dtype, copy, skipna)
#     137     raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#     139 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 140     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     142 elif is_object_dtype(arr.dtype):
#     143
#     144     # if we have a datetime/timedelta array of objects
#     145     # then coerce to a proper dtype and recall astype_nansafe
#     147     if is_datetime64_dtype(dtype):
#
# File c:\Users\Prateek Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:182, in _astype_float_to_int_nansafe(values, dtype, copy)
#     178 """
#     179 astype with a check preventing converting NaN to an meaningless integer value.
#     180 """
#     181 if not np.isfinite(values).all():
# --> 182     raise IntCastingNaNError(
#     183         "Cannot convert non-finite values (NA or inf) to integer"
#     184     )
#     185 if dtype.kind == "u":
#     186     # GH#45151
#     187     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Duration         10683 non-null  object
#  4   Total_Stops      10682 non-null  object
#  5   Additional_Info  10683 non-null  object
#  6   Price            10683 non-null  int64
#  7   Date             10683 non-null  int32
#  8   Months           10683 non-null  int32
#  9   Year             10683 non-null  int32
#  10  Dep_hour         10683 non-null  int32
#  11  Dep_min          10683 non-null  int32
#  12  Arr_hour         10683 non-null  int32
#  13  Arr_min          10683 non-null  int32
#  14  hour             10683 non-null  object
#  15  min              10683 non-null  int32
# dtypes: int32(8), int64(1), object(7)
# memory usage: 1001.7+ KB

# %%
df.head(3)
# Out:
#        Airline    Source Destination Duration Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m    non-stop         No info
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops         No info
# 2  Jet Airways     Delhi      Cochin      19h     2 stops         No info
#
#    Price  Date  Months  Year  Dep_hour  Dep_min  Arr_hour  Arr_min hour  min
# 0   3897    24       3  2019        22       20         1       10    2   50
# 1   7662     1       5  2019         5       50        13       15    7   25
# 2  13882     9       6  2019         9       25         4       25   19    0
